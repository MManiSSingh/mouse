# %% [markdown]
# # DSC106 Project03 Checkpoint
# ## Team Name: Cheese Chasers
# #### Team Members: Dallas Plunkett, Edgar Guzman, Banff Jiang, Manjot S Samra

# %% [markdown]
# ## 2. Data Set Chosen
# The data set we have chosen is the mouse data set. The aspects of the data set we plan to use is all of the four spreadsheets, but may or may not use all 26 of the mices' data. We plan on diving deeper on body temperature and daily activity, as well as how estrus affects these variables.

# %% [markdown]
# ## 3. Exploratory Graphs

# %%
from IPython.display import Image

Image(filename="dscimage1.png")

# %%
Image(filename="dscimage2.png")

# %%
Image(filename="dscimage3.png")

# %%
Image(filename="dscimage4.1.png")

# %%
Image(filename="dscimage5.1.png")

# %% [markdown]
# ## 4. Title of Graph and question we are trying to answer.
#
# As of now, our title for our graph is called "Comparison of Daily Activity and Body Temperature in Female Mice During Estrus Cycle vs. Male Mice" , and more importantly the question we are trying to answer is: How does a female mice's estrus cycle affect its daily activity and temperature compred to a male mice?
